# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('insurance_pre.csv')

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset = pd.get_dummies(dataset,drop_first=True)
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400     False        True
# 1      18  33.770         1   1725.55230      True       False
# 2      28  33.000         3   4449.46200      True       False
# 3      33  22.705         0  21984.47061      True       False
# 4      32  28.880         0   3866.85520      True       False
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830      True       False
# 1334   18  31.920         0   2205.98080     False       False
# 1335   18  36.850         0   1629.83350     False       False
# 1336   21  25.800         0   2007.94500     False       False
# 1337   61  29.070         0  29141.36030     False        True
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent = dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]

# %%
dependent = dataset[['charges']]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.30,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Corrected param_grid
param_grid = {
    'n_estimators': [10, 50, 100, 200],  # Number of trees in the forest
    'criterion': ['squared_error', 'absolute_error', 'friedman_mse', 'poisson'],  # Valid criteria for regression
    'max_features': ['sqrt', 'log2', None],  # Number of features considered for split
    'max_depth': [None, 10, 20, 30],  # Maximum depth of trees
    'min_samples_split': [2, 5, 10],  # Minimum samples required to split a node
    'min_samples_leaf': [1, 2, 4],  # Minimum samples required in a leaf node
    'bootstrap': [True, False],  # Whether to bootstrap samples
}

# Perform grid search
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit=True, verbose=3, n_jobs=-1)
grid.fit(x_train, y_train)

# Display results
print("Best Parameters:", grid.best_params_)
print("Best Score:", grid.best_score_)
# Out:
# Fitting 5 folds for each of 3456 candidates, totalling 17280 fits
# C:\Anoconda3\Lib\site-packages\sklearn\base.py:1474: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# Best Parameters: {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': None, 'max_features': None, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 50}
# Best Score: 0.8411108887330089

# %%
result = grid.cv_results_

# %%
grid_predictions = grid.predict(x_test)

# %%
from sklearn.metrics import r2_score
r_score = r2_score(y_test,grid_predictions)

# %%
r_score
# Out:
# 0.8905870139484385

# %%
table = pd.DataFrame.from_dict(result)

# %%
table
# Out:
#       mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0          0.032751      0.002249         0.004606        0.000375
# 1          0.142138      0.004201         0.009205        0.000746
# 2          0.278360      0.004393         0.013408        0.000546
# 3          0.538769      0.009894         0.022430        0.000740
# 4          0.029931      0.000959         0.004406        0.000376
# ...             ...           ...              ...             ...
# 3451       0.678710      0.006552         0.016519        0.002700
# 3452       0.038404      0.000695         0.004100        0.000206
# 3453       0.170216      0.004566         0.007916        0.000491
# 3454       0.327986      0.006115         0.010321        0.001372
# 3455       0.562374      0.025061         0.011988        0.002876
#
#      param_bootstrap param_criterion param_max_depth param_max_features  \
# 0               True   squared_error            None               sqrt
# 1               True   squared_error            None               sqrt
# 2               True   squared_error            None               sqrt
# 3               True   squared_error            None               sqrt
# 4               True   squared_error            None               sqrt
# ...              ...             ...             ...                ...
# 3451           False         poisson              30               None
# 3452           False         poisson              30               None
# 3453           False         poisson              30               None
# 3454           False         poisson              30               None
# 3455           False         poisson              30               None
#
#      param_min_samples_leaf param_min_samples_split param_n_estimators  \
# 0                         1                       2                 10
# 1                         1                       2                 50
# 2                         1                       2                100
# 3                         1                       2                200
# 4                         1                       5                 10
# ...                     ...                     ...                ...
# 3451                      4                       5                200
# 3452                      4                      10                 10
# 3453                      4                      10                 50
# 3454                      4                      10                100
# 3455                      4                      10                200
#
#                                                  params  split0_test_score  \
# 0     {'bootstrap': True, 'criterion': 'squared_erro...           0.837039
# 1     {'bootstrap': True, 'criterion': 'squared_erro...           0.858324
# 2     {'bootstrap': True, 'criterion': 'squared_erro...           0.861823
# 3     {'bootstrap': True, 'criterion': 'squared_erro...           0.864152
# 4     {'bootstrap': True, 'criterion': 'squared_erro...           0.842392
# ...                                                 ...                ...
# 3451  {'bootstrap': False, 'criterion': 'poisson', '...           0.833919
# 3452  {'bootstrap': False, 'criterion': 'poisson', '...           0.832588
# 3453  {'bootstrap': False, 'criterion': 'poisson', '...           0.832588
# 3454  {'bootstrap': False, 'criterion': 'poisson', '...           0.832588
# 3455  {'bootstrap': False, 'criterion': 'poisson', '...           0.832588
#
#       split1_test_score  split2_test_score  split3_test_score  \
# 0              0.790241           0.789425           0.787527
# 1              0.786312           0.809484           0.826226
# 2              0.795368           0.809467           0.818446
# 3              0.792615           0.802802           0.832151
# 4              0.802983           0.814333           0.816451
# ...                 ...                ...                ...
# 3451           0.762870           0.799049           0.757367
# 3452           0.767274           0.806582           0.762040
# 3453           0.767274           0.806582           0.762068
# 3454           0.767274           0.806582           0.762085
# 3455           0.767274           0.806582           0.762078
#
#       split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0              0.756303         0.792107        0.025817             2811
# 1              0.762956         0.808660        0.032754             2483
# 2              0.765621         0.810145        0.031435             2396
# 3              0.768233         0.811991        0.033172             2291
# 4              0.767890         0.808810        0.024187             2477
# ...                 ...              ...             ...              ...
# 3451           0.749263         0.780494        0.031684             3005
# 3452           0.751991         0.784095        0.030520             2916
# 3453           0.751991         0.784101        0.030516             2914
# 3454           0.751991         0.784104        0.030513             2909
# 3455           0.751991         0.784103        0.030514             2911
#
# [3456 rows x 20 columns]
